# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## More blobs

# %%
from sklearn.datasets.samples_generator import make_blobs
from sklearn.model_selection import train_test_split

# The coordinates of the centers of our blobs.
centers = [[2, 2], [-2, -2], [2, -2], [-2, 2], [0, 0]]

# Make 10,000 rows worth of data with two features representing three
# clusters, each having a standard deviation of 1.
X, y = make_blobs(
    n_samples=10000,
    centers=centers,
    cluster_std=1,
    n_features=2,
    random_state=42)

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

#Divide into training and test sets.
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.9,
    random_state=42)

# %% [markdown]
# ### K-Means

# %%
from sklearn.cluster import KMeans

# %%
y_pred = KMeans(n_clusters=5, random_state=101).fit_predict(X_train)
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_pred)
plt.show()

# %%
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred, y_train))
# Out:
# Comparing k-means clusters against the data:
# col_0    0    1    2    3    4
# row_0
# 0        1    4  175    0   12
# 1        5    2    0  165   11
# 2      202    0    2    6   16
# 3       13   16   11   13  147
# 4        0  181    3    3   12

# %% [markdown]
# ### Mean-shift

# %%
from sklearn.cluster import MeanShift, estimate_bandwidth

# Here we set the bandwidth. This function automatically derives a bandwidth
# number based on an inspection of the distances among points in the data.
bandwidth = estimate_bandwidth(X_train, quantile=0.2, n_samples=500)

bandwidth = 1.4

# %%
# Declare and fit the model.
ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X_train)

# Extract cluster assignments for each data point.
labels = ms.labels_

# Coordinates of the cluster centers.
cluster_centers = ms.cluster_centers_

# Count our clusters.
n_clusters_ = len(np.unique(labels))

print("Number of estimated clusters: {}".format(n_clusters_))
# Out:
# Number of estimated clusters: 5

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=labels)
plt.show()

print('Comparing the assigned categories to the ones in the data:')
print(pd.crosstab(y_train,labels))
# Out:
# Comparing the assigned categories to the ones in the data:
# col_0    0    1    2    3    4
# row_0
# 0      211    3    0    6    1
# 1        0    5  192    2    4
# 2        3    7    6    0  175
# 3        6    6    4  171    0
# 4       36  103   22   22   15

# %% [markdown]
# ### Spectral clustering

# %%
from sklearn.cluster import SpectralClustering

# We know we're looking for three clusters.
n_clusters=5

# Declare and fit the model.
sc = SpectralClustering(n_clusters=n_clusters)
sc.fit(X_train)

#Predicted clusters.
predict=sc.fit_predict(X_train)

#Graph results.
plt.scatter(X_train[:, 0], X_train[:, 1], c=predict)
plt.show()

print('Comparing the assigned categories to the ones in the data:')
print(pd.crosstab(y_train,predict))
# Out:
# Comparing the assigned categories to the ones in the data:
# col_0    0    1    2    3    4
# row_0
# 0        0    0  195    2   24
# 1      151    4    0    1   47
# 2        2  165    2    0   22
# 3        0    0    4  146   37
# 4        3    8    7    3  177

# %% [markdown]
# ### Affinity propagation

# %%
from sklearn.cluster import AffinityPropagation
from sklearn import metrics

# Declare the model and fit it in one statement.
# Note that you can provide arguments to the model, but we didn't.
af = AffinityPropagation().fit(X_train)
print('Done')

# Pull the number of clusters and cluster assignments for each data point.
cluster_centers_indices = af.cluster_centers_indices_
n_clusters_ = len(cluster_centers_indices)
labels = af.labels_

print('Estimated number of clusters: {}'.format(n_clusters_))
# Out:
# Done
# Estimated number of clusters: 32

# %%
from itertools import cycle

plt.figure(1)
plt.clf()

# Cycle through each cluster and graph them with a center point for the
# exemplar and lines from the exemplar to each data point in the cluster.
colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    class_members = labels == k
    cluster_center = X_train[cluster_centers_indices[k]]
    plt.plot(X_train[class_members, 0], X_train[class_members, 1], col + '.')
    plt.plot(cluster_center[0],
             cluster_center[1],
             'o',
             markerfacecolor=col,
             markeredgecolor='k')
    for x in X_train[class_members]:
        plt.plot([cluster_center[0], x[0]], [cluster_center[1], x[1]], col)

plt.title('Estimated number of clusters: {}'.format(n_clusters_))
plt.show()

# %% [markdown]
# ### Summary for this blob configuration

# %% [markdown]
# K-means and spectral cluster where the user defines how many blobs to predict worked pretty well, with K-means performs better than spectral cluster in terms of accuracy. Mean-shift performed very well when I manually adjust the number of blobs to be 5 by manually adjusting bandwidth, the bandwidth_estimate function gives a large number of clusters. The affinity propagation model predicted 32 different blobs.

# %% [markdown]
# ## More separated blobs

# %%
# The coordinates of the centers of our blobs.
centers = [[20, 20], [-20, -20], [20, -20], [-20, 20], [0, 0]]

# Make 10,000 rows worth of data with two features representing three
# clusters, each having a standard deviation of 1.
X, y = make_blobs(
    n_samples=10000,
    centers=centers,
    cluster_std=1,
    n_features=2,
    random_state=42)

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

#Divide into training and test sets.
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.9,
    random_state=42)

# %% [markdown]
# ### K-means

# %%
y_pred = KMeans(n_clusters=5, random_state=101).fit_predict(X_train)
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_pred)
plt.show()

# %%
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred, y_train))
# Out:
# Comparing k-means clusters against the data:
# col_0    0    1    2    3    4
# row_0
# 0        0    0    0    0  198
# 1        0  203    0    0    0
# 2        0    0  191    0    0
# 3      221    0    0    0    0
# 4        0    0    0  187    0

# %% [markdown]
# ### Mean-shift

# %%
bandwidth = estimate_bandwidth(X_train, quantile=0.2, n_samples=500)

bandwidth = 1.5

# %%
# Declare and fit the model.
ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X_train)

# Extract cluster assignments for each data point.
labels = ms.labels_

# Coordinates of the cluster centers.
cluster_centers = ms.cluster_centers_

# Count our clusters.
n_clusters_ = len(np.unique(labels))

print("Number of estimated clusters: {}".format(n_clusters_))
# Out:
# Number of estimated clusters: 5

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=labels)
plt.show()

print('Comparing the assigned categories to the ones in the data:')
print(pd.crosstab(y_train,labels))
# Out:
# Comparing the assigned categories to the ones in the data:
# col_0    0    1    2    3    4
# row_0
# 0      221    0    0    0    0
# 1        0    0  203    0    0
# 2        0    0    0  191    0
# 3        0    0    0    0  187
# 4        0  198    0    0    0

# %% [markdown]
# ### Spectral clustering

# %%
from sklearn.cluster import SpectralClustering

# We know we're looking for three clusters.
n_clusters=5

# Declare and fit the model.
sc = SpectralClustering(n_clusters=n_clusters)
sc.fit(X_train)

#Predicted clusters.
predict=sc.fit_predict(X_train)

#Graph results.
plt.scatter(X_train[:, 0], X_train[:, 1], c=predict)
plt.show()

print('Comparing the assigned categories to the ones in the data:')
print(pd.crosstab(y_train,predict))
# Out:
# Comparing the assigned categories to the ones in the data:
# col_0    0    1    2   3    4
# row_0
# 0      221    0    0   0    0
# 1        0    0  116  87    0
# 2        0    0    0   0  191
# 3        0  187    0   0    0
# 4      198    0    0   0    0

# %% [markdown]
# ### Affinity propagation

# %%
from sklearn.cluster import AffinityPropagation
from sklearn import metrics

# Declare the model and fit it in one statement.
# Note that you can provide arguments to the model, but we didn't.
af = AffinityPropagation().fit(X_train)
print('Done')

# Pull the number of clusters and cluster assignments for each data point.
cluster_centers_indices = af.cluster_centers_indices_
n_clusters_ = len(cluster_centers_indices)
labels = af.labels_

print('Estimated number of clusters: {}'.format(n_clusters_))
# Out:
# Done
# Estimated number of clusters: 1000

# %%
from itertools import cycle

plt.figure(1)
plt.clf()

# Cycle through each cluster and graph them with a center point for the
# exemplar and lines from the exemplar to each data point in the cluster.
colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    class_members = labels == k
    cluster_center = X_train[cluster_centers_indices[k]]
    plt.plot(X_train[class_members, 0], X_train[class_members, 1], col + '.')
    plt.plot(cluster_center[0],
             cluster_center[1],
             'o',
             markerfacecolor=col,
             markeredgecolor='k')
    for x in X_train[class_members]:
        plt.plot([cluster_center[0], x[0]], [cluster_center[1], x[1]], col)

plt.title('Estimated number of clusters: {}'.format(n_clusters_))
plt.show()

# %% [markdown]
# ### Summary for this blob configuration

# %% [markdown]
# K-means and mean-shift both worked pretty well (again, I had to manually adjust number of blobs to 5 by changing bandwidth). Spectral clustering and affinity propagation did not work so well, with spectral clustering wrongly predict a blob and slice another blob to assign to two different groups. Affinity propagation estimated 1000 clusters which is way more than we wanted.

# %% [markdown]
# ## Fewer blobs

# %%
# The coordinates of the centers of our blobs.
centers = [[2, 0], [-2, 0]]

# Make 10,000 rows worth of data with two features representing three
# clusters, each having a standard deviation of 1.
X, y = make_blobs(
    n_samples=10000,
    centers=centers,
    cluster_std=1,
    n_features=2,
    random_state=42)

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

#Divide into training and test sets.
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.9,
    random_state=42)

# %% [markdown]
# ### K-means

# %%
y_pred = KMeans(n_clusters=2, random_state=101).fit_predict(X_train)
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_pred)
plt.show()

# %%
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred, y_train))
# Out:
# Comparing k-means clusters against the data:
# col_0    0    1
# row_0
# 0       12  477
# 1      500   11

# %% [markdown]
# ### Mean-shift

# %%
bandwidth = estimate_bandwidth(X_train, quantile=0.2, n_samples=500)

#bandwidth = 1.5

# Declare and fit the model.
ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X_train)

# Extract cluster assignments for each data point.
labels = ms.labels_

# Coordinates of the cluster centers.
cluster_centers = ms.cluster_centers_

# Count our clusters.
n_clusters_ = len(np.unique(labels))

print("Number of estimated clusters: {}".format(n_clusters_))
# Out:
# Number of estimated clusters: 2

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=labels)
plt.show()

print('Comparing the assigned categories to the ones in the data:')
print(pd.crosstab(y_train,labels))
# Out:
# Comparing the assigned categories to the ones in the data:
# col_0    0    1
# row_0
# 0      500   12
# 1       11  477

# %% [markdown]
# ### Spectral clustering

# %%
from sklearn.cluster import SpectralClustering

# We know we're looking for three clusters.
n_clusters=2

# Declare and fit the model.
sc = SpectralClustering(n_clusters=n_clusters)
sc.fit(X_train)

#Predicted clusters.
predict=sc.fit_predict(X_train)

#Graph results.
plt.scatter(X_train[:, 0], X_train[:, 1], c=predict)
plt.show()

print('Comparing the assigned categories to the ones in the data:')
print(pd.crosstab(y_train,predict))
# Out:
# Comparing the assigned categories to the ones in the data:
# col_0    0    1
# row_0
# 0       13  499
# 1      477   11

# %% [markdown]
# ### Affinity propagation

# %%
from sklearn.cluster import AffinityPropagation
from sklearn import metrics

# Declare the model and fit it in one statement.
# Note that you can provide arguments to the model, but we didn't.
af = AffinityPropagation().fit(X_train)
print('Done')

# Pull the number of clusters and cluster assignments for each data point.
cluster_centers_indices = af.cluster_centers_indices_
n_clusters_ = len(cluster_centers_indices)
labels = af.labels_

print('Estimated number of clusters: {}'.format(n_clusters_))
# Out:
# Done
# Estimated number of clusters: 29

# %%
from itertools import cycle

plt.figure(1)
plt.clf()

# Cycle through each cluster and graph them with a center point for the
# exemplar and lines from the exemplar to each data point in the cluster.
colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    class_members = labels == k
    cluster_center = X_train[cluster_centers_indices[k]]
    plt.plot(X_train[class_members, 0], X_train[class_members, 1], col + '.')
    plt.plot(cluster_center[0],
             cluster_center[1],
             'o',
             markerfacecolor=col,
             markeredgecolor='k')
    for x in X_train[class_members]:
        plt.plot([cluster_center[0], x[0]], [cluster_center[1], x[1]], col)

plt.title('Estimated number of clusters: {}'.format(n_clusters_))
plt.show()

# %% [markdown]
# The first three models, k-means, mean-shift, spectral clustering worked pretty well, mean-shift correctly predicted the number of blobs, while affinity propagation still giving poor estimate of cluster number.
