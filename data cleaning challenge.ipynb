# %%
import pandas as pd
import numpy as np

# %%
articles = pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv',encoding = "ISO-8859-1")
articles.head(2)
# Out:
#    PMID/PMCID Publisher           Journal title  \
# 0         NaN       CUP  Psychological Medicine
# 1  PMC3679557       ACS       Biomacromolecules
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04

# %% [markdown]
# Let's first take a look at the data counted by journal title

# %%
articles['Journal title'].value_counts().head(20)
# Out:
# PLoS One                                           92
# PLoS ONE                                           62
# Journal of Biological Chemistry                    48
# Nucleic Acids Research                             21
# Proceedings of the National Academy of Sciences    19
# Human Molecular Genetics                           18
# PLoS Neglected Tropical Diseases                   18
# Nature Communications                              17
# PLoS Pathogens                                     15
# PLoS Genetics                                      15
# Neuroimage                                         15
# BMC Public Health                                  14
# Brain                                              14
# NeuroImage                                         14
# PLOS ONE                                           14
# Movement Disorders                                 13
# Journal of Neuroscience                            12
# ...

# %% [markdown]
# It seems that there are some dirty data, for example, there are different capitalization versions of PLOS One, in order to clean this:

# %%
articles['Journal title'].str.lower().value_counts().head(5)
# Out:
# plos one                           190
# journal of biological chemistry     53
# neuroimage                          29
# plos genetics                       24
# plos pathogens                      24
# Name: Journal title, dtype: int64

# %% [markdown]
# So the first five most common journals and total articles of each journal are listed above.

# %%
articles['clean_title'] = articles['Journal title'].str.lower()

# %%
articles['cost'] = pd.to_numeric(articles['COST (£) charged to Wellcome (inc VAT when charged)'].str[1:], errors='coerce')

# %%
articles.groupby(clean_title).mean()
# Out:
#                                                              cost
# Journal title
# academy of nutrition and dietetics                    2379.540000
# acs chemical biology                                  1418.186000
# acs chemical neuroscience                             1186.800000
# acs nano                                               668.140000
# acta crystallographica section d,  biological c...     771.420000
# acta crystallographica section d: biological cr...     773.740000
# acta crystallographica section f: structural bi...     796.635000
# acta crystallographica, section d                      757.180000
# acta crystallography d                                 774.190000
# acta d                                                 750.160000
# acta dermato venereologica                             653.960000
# acta diabetologica                                    2336.280000
# acta f                                                 754.900000
# ...

# %%
articles.groupby(clean_title).median()
# Out:
#                                                           cost
# Journal title
# academy of nutrition and dietetics                    2379.540
# acs chemical biology                                  1294.590
# acs chemical neuroscience                             1186.800
# acs nano                                               668.140
# acta crystallographica section d,  biological c...     771.420
# acta crystallographica section d: biological cr...     773.740
# acta crystallographica section f: structural bi...     796.635
# acta crystallographica, section d                      757.180
# acta crystallography d                                 774.190
# acta d                                                 750.160
# acta dermato venereologica                             653.960
# acta diabetologica                                    2336.280
# acta f                                                 754.900
# acta neuropathol                                      1901.040
# ...

# %%
articles.groupby(clean_title).std()
# Out:
#                                                              cost
# Journal title
# academy of nutrition and dietetics                            NaN
# acs chemical biology                                   507.309560
# acs chemical neuroscience                                     NaN
# acs nano                                                35.708892
# acta crystallographica section d,  biological c...            NaN
# acta crystallographica section d: biological cr...            NaN
# acta crystallographica section f: structural bi...      15.605847
# acta crystallographica, section d                             NaN
# acta crystallography d                                        NaN
# acta d                                                        NaN
# acta dermato venereologica                                    NaN
# acta diabetologica                                            NaN
# acta f                                                        NaN
# ...
